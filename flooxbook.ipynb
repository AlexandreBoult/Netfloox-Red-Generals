# %%
import pandas as pd

# %%
dfTitleBasics = pd.read_csv(r"C:\Users\tenai\Desktop\projets\projet_netfloux\projet_floux\Netfloox-Red-Generals\downloads\title.basics.tsv", encoding='utf8', nrows=1000000, delimiter='\t', na_values='\\N')
dfNameBasics = pd.read_csv(r"C:\Users\tenai\Desktop\projets\projet_netfloux\projet_floux\Netfloox-Red-Generals\downloads\name.basics.tsv", encoding='utf8', nrows=1000000, delimiter='\t', na_values='\\N')
dfTitlePrincipals = pd.read_csv(r"C:\Users\tenai\Desktop\projets\projet_netfloux\projet_floux\Netfloox-Red-Generals\downloads\title.principals.tsv", encoding='utf8', nrows=1000000, delimiter='\t', na_values='\\N')
dfRatings = pd.read_csv(r"C:\Users\tenai\Desktop\projets\projet_netfloux\projet_floux\Netfloox-Red-Generals\downloads\title.ratings.tsv", encoding='utf8', nrows=1000000, delimiter='\t', na_values='\\N')
dfAkas = pd.read_csv(r"C:\Users\tenai\Desktop\projets\projet_netfloux\projet_floux\Netfloox-Red-Generals\downloads\title.akas.tsv", encoding='utf8', nrows=1000000, delimiter='\t', na_values='\\N')

# %%
mergedTitleBasicsRatings = pd.merge(dfTitleBasics, dfRatings, how='inner', on='tconst')
#mergedTitlesAkas = pd.merge(mergedTitleBasicsRatings, dfAkas, how='inner', on='titleId')
mergedTitlePrincipals = pd.merge(mergedTitleBasicsRatings, dfTitlePrincipals, how='inner', on='tconst')
mergedDF = pd.merge(mergedTitlePrincipals, dfNameBasics, how='inner', on='nconst')

# %%
mergedDF
# Out:
#            tconst titleType                                 primaryTitle  \
# 0       tt0000001     short                                   Carmencita
# 1       tt0000005     short                             Blacksmith Scene
# 2       tt0000006     short                            Chinese Opium Den
# 3       tt0000007     short  Corbett and Courtney Before the Kinetograph
# 4       tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# ...           ...       ...                                          ...
# 775526  tt0116647     video                 Invasion for Flesh and Blood
# 775527  tt0116647     video                 Invasion for Flesh and Blood
# 775528  tt0116647     video                 Invasion for Flesh and Blood
# 775529  tt0116647     video                 Invasion for Flesh and Blood
# 775530  tt0116647     video                 Invasion for Flesh and Blood
#
#                                       originalTitle  isAdult  startYear  \
# 0                                        Carmencita        0     1894.0
# 1                                  Blacksmith Scene        0     1893.0
# 2                                 Chinese Opium Den        0     1894.0
# 3       Corbett and Courtney Before the Kinetograph        0     1894.0
# 4            Edison Kinetoscopic Record of a Sneeze        0     1894.0
# ...                                             ...      ...        ...
# 775526  A Taste for Flesh and Blood 2: Raising Hell        0     1991.0
# 775527  A Taste for Flesh and Blood 2: Raising Hell        0     1991.0
# 775528  A Taste for Flesh and Blood 2: Raising Hell        0     1991.0
# 775529  A Taste for Flesh and Blood 2: Raising Hell        0     1991.0
# 775530  A Taste for Flesh and Blood 2: Raising Hell        0     1991.0
#
#         endYear  runtimeMinutes                genres  averageRating  ...  \
# 0           NaN             1.0     Documentary,Short            5.7  ...
# 1           NaN             1.0          Comedy,Short            6.2  ...
# 2           NaN             1.0                 Short            5.0  ...
# 3           NaN             1.0           Short,Sport            5.4  ...
# 4           NaN             1.0     Documentary,Short            5.4  ...
# ...         ...             ...                   ...            ...  ...
# 775526      NaN            90.0  Comedy,Horror,Sci-Fi            3.8  ...
# 775527      NaN            90.0  Comedy,Horror,Sci-Fi            3.8  ...
# 775528      NaN            90.0  Comedy,Horror,Sci-Fi            3.8  ...
# 775529      NaN            90.0  Comedy,Horror,Sci-Fi            3.8  ...
# 775530      NaN            90.0  Comedy,Horror,Sci-Fi            3.8  ...
#
#         ordering     nconst  category  job         characters  \
# 0              2  nm0005690  director  NaN                NaN
# 1              3  nm0005690  director  NaN                NaN
# 2              1  nm0005690  director  NaN                NaN
# 3              3  nm0005690  director  NaN                NaN
# 4              2  nm0005690  director  NaN                NaN
# ...          ...        ...       ...  ...                ...
# 775526         2  nm0228291     actor  NaN     ["Prof. Herz"]
# 775527         3  nm0162802     actor  NaN  ["Golden Slayer"]
# 775528         4  nm0194831   actress  NaN     ["Dr. Chekov"]
# 775529         5  nm0228292  director  NaN                NaN
# 775530         6  nm0030436  composer  NaN                NaN
#
#                  primaryName birthYear  deathYear  \
# 0       William K.L. Dickson    1860.0     1935.0
# 1       William K.L. Dickson    1860.0     1935.0
# 2       William K.L. Dickson    1860.0     1935.0
# 3       William K.L. Dickson    1860.0     1935.0
# 4       William K.L. Dickson    1860.0     1935.0
# ...                      ...       ...        ...
# 775526    Warren Disbrow Sr.    1921.0     2020.0
# 775527         Jim Cironella       NaN        NaN
# 775528    Adrienne D'Accardi    1969.0     2010.0
# 775529     Warren F. Disbrow    1957.0        NaN
# 775530    Anthony Annunziata       NaN        NaN
#
#                             primaryProfession  \
# 0           cinematographer,director,producer
# 1           cinematographer,director,producer
# 2           cinematographer,director,producer
# 3           cinematographer,director,producer
# 4           cinematographer,director,producer
# ...                                       ...
# 775526  actor,camera_department,miscellaneous
# 775527        producer,music_department,actor
# 775528                                actress
# 775529                 director,writer,editor
# 775530               cinematographer,composer
#
#                                    knownForTitles
# 0         tt0219560,tt0308254,tt1496763,tt1428455
# 1         tt0219560,tt0308254,tt1496763,tt1428455
# 2         tt0219560,tt0308254,tt1496763,tt1428455
# 3         tt0219560,tt0308254,tt1496763,tt1428455
# 4         tt0219560,tt0308254,tt1496763,tt1428455
# ...                                           ...
# 775526    tt0202442,tt1337627,tt1172055,tt0762131
# 775527  tt0116647,tt13993986,tt1467244,tt24517650
# 775528                                  tt0116647
# 775529    tt1337627,tt0116647,tt0762131,tt0202442
# 775530                        tt0116647,tt0199479
#
# [775531 rows x 21 columns]

# %%
mergedDF = mergedTitleBasicsRatings.dropna(inplace=True)

# %%
mergedDF

# %%
y = mergedTitleBasicsRatings['averageRating']
X = mergedTitleBasicsRatings[['startYear', 'runtimeMinutes']]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestRegressor

# %%
scaler = StandardScaler()
encoder = OneHotEncoder()
vectorizer = CountVectorizer()
regressor = RandomForestRegressor(n_estimators= 100, max_depth=3, criterion="squared_error")
ct = ColumnTransformer([
    ('num', scaler, ['runtimeMinutes', 'startYear'])
    #('cat', encoder, ['genres'])
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=23)

pipe = Pipeline([
    ('transformer', ct),
    ('regressor', regressor)
    ])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['runtimeMinutes',
#                                                    'startYear'])])),
#                 ('regressor', RandomForestRegressor(max_depth=3))])

# %%
predictions = pipe.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_test, predictions)
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Absolute Error (MAE): 0.8542244252044231

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'regressor__max_depth': [None, 10, 20, 30],
              'regressor__min_samples_split': [2, 5, 10],
              'regressor__min_samples_leaf': [1, 2, 4]}

# %%
grid_search = GridSearchCV(pipe, param_grid, cv=5, scoring='neg_mean_absolute_error')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['runtimeMinutes',
#                                                                           'startYear'])])),
#                                        ('regressor',
#                                         RandomForestRegressor(max_depth=3))]),
#              param_grid={'regressor__max_depth': [None, 10, 20, 30],
#                          'regressor__min_samples_leaf': [1, 2, 4],
#                          'regressor__min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_absolute_error')

# %%
print("Meilleurs hyperparamètres :", grid_search.best_params_)
# Out:
# Meilleurs hyperparamètres : {'regressor__max_depth': 10, 'regressor__min_samples_leaf': 4, 'regressor__min_samples_split': 5}

# %%
param_grid = {'regressor__max_depth': [10],
              'regressor__min_samples_split': [10],
              'regressor__min_samples_leaf': [4]}

# %%
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, predictions)
print(f"Mean Absolute Error (MAE) avec les meilleurs hyperparamètres : {mae}")
# Out:
# Mean Absolute Error (MAE) avec les meilleurs hyperparamètres : 0.8477520272022939
